# %%
import showast2

# %%
# %%showast
# assert 1 + 2, "NOOP because 1 + 2 is truthy"

# %%
# %%showast
# a = 1
# b = a + 2
# b /= 2.

# %%
# %%showast
# x.y.z().t

# %%
# %%showast
# def abc():
#     for x in 'abc':
#         print(x)
#     return 0

# %%
# %%showast
# a, b = [x for x in y if x.z]

# %%
# %%showast
# @decorator()
# def decorated():
#     import time
#     yield time.time()

# %%
# showast2 can also be used to visualize inspectable objects

from showast2 import show_source

import antigravity
show_source(antigravity)

# %%
import random
show_source(random.choice)

# %%
import contextlib
show_source(contextlib.closing.__enter__)
show_source(contextlib.closing.__exit__)

# %%
# styling options can also be set

from showast2 import Settings
Settings['font'] = 'Century'
Settings['shape'] = 'oval'
Settings['nonterminal_color'] = '#7733AA'

# %%
# %%showast
# def add(x, y):
#     return x + y

# %%
# nltk and pillow can be used as an alternate rendering engine

from showast2 import Renderers
Settings['renderer'] = Renderers.nltk

# reset styling:
Settings['font'] = 'courier'
Settings['shape'] = 'none'
Settings['nonterminal_color'] = '#004080'

# %%
# %%showast
# while b != 0:
#     if a > b:
#         a = a - b
#     else:
#         b = b - a
# print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_ipython().run_cell_magic('showast', '', 'while b != 0:\n    if a > b:\n        a = a - b\n    else:\n        b = b - a\nprint(a)\n')
#
# File ~/.virtualenvs/python3.13/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Projects/show_ast/showast2/__init__.py:69, in showast(__, cell)
#      66 @register_cell_magic
#      67 def showast(__, cell):
#      68     m = ast.parse(cell)
# ---> 69     show_ast(m)
#
# File ~/Projects/show_ast/showast2/__init__.py:63, in show_ast(module, settings)
#      60 renderer = importlib.util.module_from_spec(spec)
#      61 spec.loader.exec_module(renderer)
# ---> 63 display(renderer.render(node, settings))
#
# File ~/Projects/show_ast/showast2/rendering/nltk.py:111, in render(node, settings)
#     107 """
#     108 Given an AST node and settings, return a displayable object.
#     109 """
#     110 tree = handle_ast(node, settings['omit_docstrings'])
# --> 111 with _tree_image(tree, settings) as fname:
#     112     return IPImage(filename=fname)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/contextlib.py:141, in _GeneratorContextManager.__enter__(self)
#     139 del self.args, self.kwds, self.func
#     140 try:
# --> 141     return next(self.gen)
#     142 except StopIteration:
#     143     raise RuntimeError("generator didn't yield") from None
#
# File ~/Projects/show_ast/showast2/rendering/nltk.py:85, in _tree_image(tree, settings)
#      82 @contextlib.contextmanager
#      83 def _tree_image(tree, settings):
#      84     t = Tree.fromstring(tree)
# ---> 85     tv = SizableTreeView(t, settings)
#      86     tv._cframe.print_to_file('.temp.ps')
#      87     im = Image.open('.temp.ps')
#
# File ~/Projects/show_ast/showast2/rendering/nltk.py:76, in SizableTreeView.__init__(self, tree, settings)
#      74 widget['yspace'] = int(settings['scale'] * widget['yspace'])
#      75 self._widgets.append(widget)
# ---> 76 cf.add_widget(widget, 0, 0)
#      78 self._layout()
#      79 self._cframe.pack(expand=1, fill='both', side='left')
#
# File ~/.virtualenvs/python3.13/lib/python3.13/site-packages/nltk/draw/util.py:1917, in CanvasFrame.add_widget(self, canvaswidget, x, y)
#    1914 canvaswidget.move(x - x1, y - y1)
#    1916 # Register with scrollwatcher.
# -> 1917 self._scrollwatcher.add_child(canvaswidget)
#
# File ~/.virtualenvs/python3.13/lib/python3.13/site-packages/nltk/draw/util.py:1716, in ScrollWatcherWidget.add_child(self, canvaswidget)
#    1706 """
#    1707 Add a new canvas widget to the scroll-watcher.  The
#    1708 scroll-watcher will ensure that the new canvas widget is
#    (...)
#    1713 :rtype: None
#    1714 """
#    1715 self._add_child_widget(canvaswidget)
# -> 1716 self.update(canvaswidget)
#
# File ~/.virtualenvs/python3.13/lib/python3.13/site-packages/nltk/draw/util.py:393, in CanvasWidget.update(self, child)
#     390 self.__updating = 1
#     392 # Update this CanvasWidget.
# --> 393 self._update(child)
#     395 # Propagate update request to the parent.
#     396 if self.__parent:
#
# File ~/.virtualenvs/python3.13/lib/python3.13/site-packages/nltk/draw/util.py:1734, in ScrollWatcherWidget._update(self, child)
#    1733 def _update(self, child):
# -> 1734     self._adjust_scrollregion()
#
# File ~/.virtualenvs/python3.13/lib/python3.13/site-packages/nltk/draw/util.py:1743, in ScrollWatcherWidget._adjust_scrollregion(self)
#    1741 bbox = self.bbox()
#    1742 canvas = self.canvas()
# -> 1743 scrollregion = [int(n) for n in canvas["scrollregion"].split()]
#    1744 if len(scrollregion) != 4:
#    1745     return
#
# ValueError: invalid literal for int() with base 10: '10c'

# %% [markdown]
# ## Showing AST from a String Literal

# %%
from showast2 import show_text

show_text("""def add(x, y):
    return x + y""")

# %% [markdown]
# ## Showing Source Column and Line Locations for Each Node

# %%
# revert to the default settings, except that `omit_location_info` is set False

Settings.update(dict(
    # Styling options:
    scale=2,
    font='courier',
    shape='none',
    terminal_color='#008040',
    nonterminal_color='#004080',

    # AST display options:
    omit_module=True,
    omit_docstrings=True,

    # By default omit_location_info is True
    omit_location_info=False,
    locations_format="L{begin[0]}:{begin[1]}-L{end[0]}:{end[1]}",

    # Rendering engine is expected to expose "render" function
    renderer=Renderers.graphviz,
))

# %%
# %%showast
# def add(x, y):
#     return x + y
